# %% [markdown]
# ## Perception + Amenity

# %%
import geopandas as gpd
import pandas as pd
import json

# Load GeoParquet file
gdf = gpd.read_parquet(r'D:\IaaC\2ND_YEAR\THESIS\LLM_Based_UrbanABM\Documentation\agent_recording_session_2026-04-04T12-35-56.parquet')

# Basic statistics
print(f"Total records: {len(gdf)}")
print(f"Unique agents: {gdf['agent_id'].nunique()}")
print(f"Steps: {gdf['step'].min()} to {gdf['step'].max()}")

# Parse JSON columns
gdf['needs'] = gdf['needs_json'].apply(json.loads)
gdf['cognition'] = gdf['cognition_state_json'].apply(json.loads)

# Extract needs into separate columns
gdf['hunger'] = gdf['needs'].apply(lambda x: x.get('hunger', 0))
gdf['energy'] = gdf['needs'].apply(lambda x: x.get('energy', 0))
gdf['social'] = gdf['needs'].apply(lambda x: x.get('social', 0))

# Filter by archetype
residents = gdf[gdf['archetype'] == 'resident']
tourists = gdf[gdf['archetype'] == 'tourist']

# Spatial analysis: create trajectory for each agent
trajectories = gdf.dissolve(by='agent_id', as_index=False)

# Visualize agent density
from shapely.geometry import Point
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(12, 8))
gdf.plot(ax=ax, markersize=2, alpha=0.3, column='archetype', categorical=True)
plt.title("Agent Spatial Distribution")
plt.show()
# Out:
# Total records: 15000
# Unique agents: 15
# Steps: 6 to 1005

# %% [markdown]
# ## Perception only

# %%
import geopandas as gpd
import pandas as pd
import json

# Load GeoParquet file
gdf = gpd.read_parquet(r"..\Documentation\agent_recording_session_2026-03-26T16-59-59_perception.parquet")

# Basic statistics
print(f"Total records: {len(gdf)}")
print(f"Unique agents: {gdf['agent_id'].nunique()}")
print(f"Steps: {gdf['step'].min()} to {gdf['step'].max()}")

# Parse JSON columns
gdf['needs'] = gdf['needs_json'].apply(json.loads)
gdf['cognition'] = gdf['cognition_state_json'].apply(json.loads)

# Extract needs into separate columns
gdf['hunger'] = gdf['needs'].apply(lambda x: x.get('hunger', 0))
gdf['energy'] = gdf['needs'].apply(lambda x: x.get('energy', 0))
gdf['social'] = gdf['needs'].apply(lambda x: x.get('social', 0))

# Filter by archetype
residents = gdf[gdf['archetype'] == 'resident']
tourists = gdf[gdf['archetype'] == 'tourist']

# Spatial analysis: create trajectory for each agent
trajectories = gdf.dissolve(by='agent_id', as_index=False)

# Visualize agent density
from shapely.geometry import Point
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(12, 8))
gdf.plot(ax=ax, markersize=2, alpha=0.3, column='archetype', categorical=True)
plt.title("Agent Spatial Distribution")
plt.show()
# Out:
# Total records: 5000
# Unique agents: 50
# Steps: 11 to 112

# %% [markdown]
# ## Amenity Only

# %%
import geopandas as gpd
import pandas as pd
import json

# Load GeoParquet file
gdf = gpd.read_parquet(r"..\Documentation\agent_recording_session_2026-03-28T01-12-29_amenities.parquet")

# Basic statistics
print(f"Total records: {len(gdf)}")
print(f"Unique agents: {gdf['agent_id'].nunique()}")
print(f"Steps: {gdf['step'].min()} to {gdf['step'].max()}")

# Parse JSON columns
gdf['needs'] = gdf['needs_json'].apply(json.loads)
gdf['cognition'] = gdf['cognition_state_json'].apply(json.loads)

# Extract needs into separate columns
gdf['hunger'] = gdf['needs'].apply(lambda x: x.get('hunger', 0))
gdf['energy'] = gdf['needs'].apply(lambda x: x.get('energy', 0))
gdf['social'] = gdf['needs'].apply(lambda x: x.get('social', 0))

# Filter by archetype
residents = gdf[gdf['archetype'] == 'resident']
tourists = gdf[gdf['archetype'] == 'tourist']

# Spatial analysis: create trajectory for each agent
trajectories = gdf.dissolve(by='agent_id', as_index=False)

# Visualize agent density
from shapely.geometry import Point
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(12, 8))
gdf.plot(ax=ax, markersize=2, alpha=0.3, column='archetype', categorical=True)
plt.title("Agent Spatial Distribution")
plt.show()
# Out:
# Total records: 5000
# Unique agents: 15
# Steps: 6 to 338

# %%
import duckdb  as dkb

con = dkb.connect(r"..\tracking_data\agent_tracking.duckdb", read_only=True)
# Out:
# ---------------------------------------------------------------------------
# IOException                               Traceback (most recent call last)
# Cell In[13], line 3
#       1 import duckdb  as dkb
# ----> 3 con = dkb.connect(r"..\tracking_data\agent_tracking.duckdb", read_only=True)
#
# IOException: IO Error: Cannot open file "\\?\D:\IaaC\2ND_YEAR\THESIS\LLM_Based_UrbanABM\Documentation\tracking_data\agent_tracking.duckdb": The process cannot access the file because it is being used by another process.
#
# File is already open in
# C:\Python313\python.exe (PID 41424)
