# %% [markdown]
# ## Perception + Amenity

# %%
import geopandas as gpd
import pandas as pd
import json

# Load GeoParquet file
gdf = gpd.read_parquet(r"..\Documentation\agent_recording_session_2026-03-29T00-40-26_both.parquet")

# Basic statistics
print(f"Total records: {len(gdf)}")
print(f"Unique agents: {gdf['agent_id'].nunique()}")
print(f"Steps: {gdf['step'].min()} to {gdf['step'].max()}")

# Parse JSON columns
gdf['needs'] = gdf['needs_json'].apply(json.loads)
gdf['cognition'] = gdf['cognition_state_json'].apply(json.loads)

# Extract needs into separate columns
gdf['hunger'] = gdf['needs'].apply(lambda x: x.get('hunger', 0))
gdf['energy'] = gdf['needs'].apply(lambda x: x.get('energy', 0))
gdf['social'] = gdf['needs'].apply(lambda x: x.get('social', 0))

# Filter by archetype
residents = gdf[gdf['archetype'] == 'resident']
tourists = gdf[gdf['archetype'] == 'tourist']

# Spatial analysis: create trajectory for each agent
trajectories = gdf.dissolve(by='agent_id', as_index=False)

# Visualize agent density
from shapely.geometry import Point
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(12, 8))
gdf.plot(ax=ax, markersize=2, alpha=0.3, column='archetype', categorical=True)
plt.title("Agent Spatial Distribution")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File d:\IaaC\2ND_YEAR\THESIS\LLM_Based_UrbanABM\UrbanABM\Lib\site-packages\geopandas\io\arrow.py:654, in _read_parquet_schema_and_metadata(path, filesystem)
#     653 try:
# --> 654     schema = parquet.ParquetDataset(path, filesystem=filesystem, **kwargs).schema
#     655 except Exception:
#
# File d:\IaaC\2ND_YEAR\THESIS\LLM_Based_UrbanABM\UrbanABM\Lib\site-packages\pyarrow\parquet\core.py:1438, in ParquetDataset.__init__(self, path_or_paths, filesystem, schema, filters, read_dictionary, binary_type, list_type, memory_map, buffer_size, partitioning, ignore_prefixes, pre_buffer, coerce_int96_timestamp_unit, decryption_properties, thrift_string_size_limit, thrift_container_size_limit, page_checksum_verification, arrow_extensions_enabled)
#    1435     partitioning = ds.HivePartitioning.discover(
#    1436         infer_dictionary=True)
# -> 1438 self._dataset = ds.dataset(path_or_paths, filesystem=filesystem,
#    1439                            schema=schema, format=parquet_format,
#    1440                            partitioning=partitioning,
#    1441                            ignore_prefixes=ignore_prefixes)
#
# File d:\IaaC\2ND_YEAR\THESIS\LLM_Based_UrbanABM\UrbanABM\Lib\site-packages\pyarrow\dataset.py:790, in dataset(source, schema, format, filesystem, partitioning, partition_base_dir, exclude_invalid_files, ignore_prefixes)
#     789 if _is_path_like(source):
# --> 790     return _filesystem_dataset(source, **kwargs)
#     791 elif isinstance(source, (tuple, list)):
#
# File d:\IaaC\2ND_YEAR\THESIS\LLM_Based_UrbanABM\UrbanABM\Lib\site-packages\pyarrow\dataset.py:472, in _filesystem_dataset(source, schema, filesystem, partitioning, format, partition_base_dir, exclude_invalid_files, selector_ignore_prefixes)
#     471 else:
# --> 472     fs, paths_or_selector = _ensure_single_source(source, filesystem)
#     474 options = FileSystemFactoryOptions(
#     475     partitioning=partitioning,
#     476     partition_base_dir=partition_base_dir,
#     477     exclude_invalid_files=exclude_invalid_files,
#     478     selector_ignore_prefixes=selector_ignore_prefixes
#     479 )
#
# File d:\IaaC\2ND_YEAR\THESIS\LLM_Based_UrbanABM\UrbanABM\Lib\site-packages\pyarrow\dataset.py:437, in _ensure_single_source(path, filesystem)
#     436 else:
# --> 437     raise FileNotFoundError(path)
#     439 return filesystem, paths_or_selector
#
# FileNotFoundError: ../Documentation/agent_recording_session_2026-03-29T00-40-26_both.parquet
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 6
#       3 import json
#       5 # Load GeoParquet file
# ----> 6 gdf = gpd.read_parquet(r"..\Documentation\agent_recording_session_2026-03-29T00-40-26_both.parquet")
#       8 # Basic statistics
#       9 print(f"Total records: {len(gdf)}")
#
# File d:\IaaC\2ND_YEAR\THESIS\LLM_Based_UrbanABM\UrbanABM\Lib\site-packages\geopandas\io\arrow.py:772, in _read_parquet(path, columns, storage_options, bbox, to_pandas_kwargs, **kwargs)
#     768 filesystem, path = _get_filesystem_path(
#     769     path, filesystem=filesystem, storage_options=storage_options
#     770 )
#     771 path = _expand_user(path)
# --> 772 schema, metadata = _read_parquet_schema_and_metadata(path, filesystem)
#     774 geo_metadata = _validate_and_decode_metadata(metadata)
#     775 if len(geo_metadata["columns"]) == 0:
#
# File d:\IaaC\2ND_YEAR\THESIS\LLM_Based_UrbanABM\UrbanABM\Lib\site-packages\geopandas\io\arrow.py:656, in _read_parquet_schema_and_metadata(path, filesystem)
#     654     schema = parquet.ParquetDataset(path, filesystem=filesystem, **kwargs).schema
#     655 except Exception:
# --> 656     schema = parquet.read_schema(path, filesystem=filesystem)
#     658 metadata = schema.metadata
#     660 # read metadata separately to get the raw Parquet FileMetaData metadata
#     661 # (pyarrow doesn't properly exposes those in schema.metadata for files
#     662 # created by GDAL - https://issues.apache.org/jira/browse/ARROW-16688)
#
# File d:\IaaC\2ND_YEAR\THESIS\LLM_Based_UrbanABM\UrbanABM\Lib\site-packages\pyarrow\parquet\core.py:2421, in read_schema(where, memory_map, decryption_properties, filesystem)
#    2419 file_ctx = nullcontext()
#    2420 if filesystem is not None:
# -> 2421     file_ctx = where = filesystem.open_input_file(where)
#    2423 with file_ctx:
#    2424     file = ParquetFile(
#    2425         where, memory_map=memory_map,
#    2426         decryption_properties=decryption_properties)
#
# File d:\IaaC\2ND_YEAR\THESIS\LLM_Based_UrbanABM\UrbanABM\Lib\site-packages\pyarrow\_fs.pyx:815, in pyarrow._fs.FileSystem.open_input_file()
#
# File d:\IaaC\2ND_YEAR\THESIS\LLM_Based_UrbanABM\UrbanABM\Lib\site-packages\pyarrow\error.pxi:155, in pyarrow.lib.pyarrow_internal_check_status()
#
# File d:\IaaC\2ND_YEAR\THESIS\LLM_Based_UrbanABM\UrbanABM\Lib\site-packages\pyarrow\error.pxi:92, in pyarrow.lib.check_status()
#
# FileNotFoundError: [WinError 3] Failed to open local file '../Documentation/agent_recording_session_2026-03-29T00-40-26_both.parquet'. Detail: [Windows error 3] The system cannot find the path specified.

# %% [markdown]
# ## Perception only

# %%
import geopandas as gpd
import pandas as pd
import json

# Load GeoParquet file
gdf = gpd.read_parquet(r"..\Documentation\agent_recording_session_2026-03-26T16-59-59_perception.parquet")

# Basic statistics
print(f"Total records: {len(gdf)}")
print(f"Unique agents: {gdf['agent_id'].nunique()}")
print(f"Steps: {gdf['step'].min()} to {gdf['step'].max()}")

# Parse JSON columns
gdf['needs'] = gdf['needs_json'].apply(json.loads)
gdf['cognition'] = gdf['cognition_state_json'].apply(json.loads)

# Extract needs into separate columns
gdf['hunger'] = gdf['needs'].apply(lambda x: x.get('hunger', 0))
gdf['energy'] = gdf['needs'].apply(lambda x: x.get('energy', 0))
gdf['social'] = gdf['needs'].apply(lambda x: x.get('social', 0))

# Filter by archetype
residents = gdf[gdf['archetype'] == 'resident']
tourists = gdf[gdf['archetype'] == 'tourist']

# Spatial analysis: create trajectory for each agent
trajectories = gdf.dissolve(by='agent_id', as_index=False)

# Visualize agent density
from shapely.geometry import Point
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(12, 8))
gdf.plot(ax=ax, markersize=2, alpha=0.3, column='archetype', categorical=True)
plt.title("Agent Spatial Distribution")
plt.show()
# Out:
# Total records: 5000
# Unique agents: 50
# Steps: 11 to 112

# %% [markdown]
# ## Amenity Only

# %%
import geopandas as gpd
import pandas as pd
import json

# Load GeoParquet file
gdf = gpd.read_parquet(r"..\Documentation\agent_recording_session_2026-03-28T01-12-29_amenities.parquet")

# Basic statistics
print(f"Total records: {len(gdf)}")
print(f"Unique agents: {gdf['agent_id'].nunique()}")
print(f"Steps: {gdf['step'].min()} to {gdf['step'].max()}")

# Parse JSON columns
gdf['needs'] = gdf['needs_json'].apply(json.loads)
gdf['cognition'] = gdf['cognition_state_json'].apply(json.loads)

# Extract needs into separate columns
gdf['hunger'] = gdf['needs'].apply(lambda x: x.get('hunger', 0))
gdf['energy'] = gdf['needs'].apply(lambda x: x.get('energy', 0))
gdf['social'] = gdf['needs'].apply(lambda x: x.get('social', 0))

# Filter by archetype
residents = gdf[gdf['archetype'] == 'resident']
tourists = gdf[gdf['archetype'] == 'tourist']

# Spatial analysis: create trajectory for each agent
trajectories = gdf.dissolve(by='agent_id', as_index=False)

# Visualize agent density
from shapely.geometry import Point
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(12, 8))
gdf.plot(ax=ax, markersize=2, alpha=0.3, column='archetype', categorical=True)
plt.title("Agent Spatial Distribution")
plt.show()
# Out:
# Total records: 5000
# Unique agents: 15
# Steps: 6 to 338
